# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.18.1                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'RUWENN41AQNZCAN1GGZU5DOAWFN2BGP1CDMYS42EOWHV1UKI' # your Foursquare ID
CLIENT_SECRET = 'AVQNOUSATC1LPMERL4EESPIYPH1GLXSKHAJVGVFTTAV4SHY1' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID:' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID:RUWENN41AQNZCAN1GGZU5DOAWFN2BGP1CDMYS42EOWHV1UKI
# CLIENT_SECRET:AVQNOUSATC1LPMERL4EESPIYPH1GLXSKHAJVGVFTTAV4SHY1

# %%
address = 'Nevsky prospect, St. Petersburg, Russian Federation'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 59.9356467 30.3235057

# %%
search_query = 'Bakery'
radius = 15000
print(search_query + ' .... OK!')
# Out:
# Bakery .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RUWENN41AQNZCAN1GGZU5DOAWFN2BGP1CDMYS42EOWHV1UKI&client_secret=AVQNOUSATC1LPMERL4EESPIYPH1GLXSKHAJVGVFTTAV4SHY1&ll=59.9356467,30.3235057&v=20180604&query=Bakery&radius=15000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c65c880351e3d4e701dbf01'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '4cac69f35a1e9521858d8ece',
#     'location': {'address': 'ТЦ «Владимирский Пассаж»',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Владимирский просп., 19',
#      'distance': 1546,
#      'formattedAddress': ['ТЦ «Владимирский Пассаж» (Владимирский просп., 19)',
#       '190000, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92842988334725,
#        'lng': 30.34719816837263}],
#      'lat': 59.92842988334725,
#      'lng': 30.34719816837263,
#      'postalCode': '190000',
#      'state': 'Санкт-Петербург'},
#     'name': 'British Bakery / Британские пекарни',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '4f6ab59ce4b01a6dd5564f05',
#     'location': {'address': 'Греческий просп., 25',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': '8-я Советская ул.',
#      'distance': 2585,
#      'formattedAddress': ['Греческий просп., 25 (8-я Советская ул.)',
#       '191036, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.93804199167404,
#        'lng': 30.369622844811605}],
#      'lat': 59.93804199167404,
#      'lng': 30.369622844811605,
#      'postalCode': '191036',
#      'state': 'Санкт-Петербург'},
#     'name': 'British Bakery / Британские пекарни',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '4ca49c67d7c33704febfaa62',
#     'location': {'address': 'Большой просп. П.С., 80',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'ул. Плуталова',
#      'distance': 3243,
#      'formattedAddress': ['Большой просп. П.С., 80 (ул. Плуталова)',
#       '197136, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.96381249430763,
#        'lng': 30.3086342677935}],
#      'lat': 59.96381249430763,
#      'lng': 30.3086342677935,
#      'postalCode': '197136',
#      'state': 'Санкт-Петербург'},
#     'name': 'British Bakery / Британские пекарни',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '5042161fe4b0a10506dd7bb8',
#     'location': {'address': 'ТЦ «Электра»',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Московский просп., 137',
#      'distance': 6092,
#      'formattedAddress': ['ТЦ «Электра» (Московский просп., 137)',
#       '196105, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.880979699130364,
#        'lng': 30.318230421980388}],
#      'lat': 59.880979699130364,
#      'lng': 30.318230421980388,
#      'postalCode': '196105',
#      'state': 'Санкт-Петербург'},
#     'name': 'British Bakery / Британские пекарни',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'primary': True,
#       'shortName': 'Desserts'}],
#     'hasPerk': False,
#     'id': '5230626311d22f9e9d411cd5',
#     'location': {'address': 'ТРК «Радуга»',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'просп. Космонавтов, 14',
#      'distance': 7508,
#      'formattedAddress': ['ТРК «Радуга» (просп. Космонавтов, 14)',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.86949544195557,
#        'lng': 30.349766027315997}],
#      'lat': 59.86949544195557,
#      'lng': 30.349766027315997,
#      'state': 'Санкт-Петербург'},
#     'name': 'British Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '56cdad3fcd100886b3be7795',
#     'location': {'address': 'Новочеркасский пр. 41/14',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 4920,
#      'formattedAddress': ['Новочеркасский пр. 41/14',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92942807232159,
#        'lng': 30.410845737340207}],
#      'lat': 59.92942807232159,
#      'lng': 30.410845737340207,
#      'state': 'Санкт-Петербург'},
#     'name': 'British Bakery / Британские пекарни',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '4cc927047151721ebc246537',
#     'location': {'address': 'ТРК «Гранд Каньон»',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'просп. Энгельса, 154',
#      'distance': 13712,
#      'formattedAddress': ['ТРК «Гранд Каньон» (просп. Энгельса, 154)',
#       '194358, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 60.058651488772085,
#        'lng': 30.336684295048464}],
#      'lat': 60.058651488772085,
#      'lng': 30.336684295048464,
#      'postalCode': '194358',
#      'state': 'Санкт-Петербург'},
#     'name': 'British Bakery (Британские пекарни)',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '594562113af9883484e27ef3',
#     'location': {'address': '102 Фонтанки реки набережная',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1347,
#      'formattedAddress': ['102 Фонтанки реки набережная',
#       '191180, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92354615146577,
#        'lng': 30.324066163107787}],
#      'lat': 59.92354615146577,
#      'lng': 30.324066163107787,
#      'postalCode': '191180',
#      'state': 'Санкт-Петербург'},
#     'name': 'Мишка Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '59c3a1db2e268037db0e254e',
#     'location': {'address': 'ул. Марата, 30',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1903,
#      'formattedAddress': ['ул. Марата, 30',
#       '191040, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92643746301236,
#        'lng': 30.352257914923825}],
#      'lat': 59.92643746301236,
#      'lng': 30.352257914923825,
#      'postalCode': '191040',
#      'state': 'Санкт-Петербург'},
#     'name': "Babe's Bakery",
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '4bb593bb941ad13af0641ee3',
#     'location': {'address': 'Малая Морская ул., 7',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 552,
#      'formattedAddress': ['Малая Морская ул., 7',
#       '191186, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.935959526930766,
#        'lng': 30.313610535583198}],
#      'lat': 59.935959526930766,
#      'lng': 30.313610535583198,
#      'postalCode': '191186',
#      'state': 'Санкт-Петербург'},
#     'name': 'Буше',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'primary': True,
#       'shortName': 'Café'}],
#     'hasPerk': False,
#     'id': '596bfb5cc0cacb4451055242',
#     'location': {'address': 'наб. Обводного канала, 108',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 3177,
#      'formattedAddress': ['наб. Обводного канала, 108',
#       '196084, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.90766570516298,
#        'lng': 30.31225957615085}],
#      'lat': 59.90766570516298,
#      'lng': 30.31225957615085,
#      'postalCode': '196084',
#      'state': 'Санкт-Петербург'},
#     'name': 'Sisters Coffee & Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '5b6019bcb1538e002c1cfa4f',
#     'location': {'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 12006,
#      'formattedAddress': ['196158, Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.827793,
#        'lng': 30.325792}],
#      'lat': 59.827793,
#      'lng': 30.325792,
#      'neighborhood': 'Округ Звёздное',
#      'postalCode': '196158',
#      'state': 'Санкт-Петербург'},
#     'name': 'мишка Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '53637d27498e173691316bc2',
#     'location': {'address': 'Потемкинская, 9',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 2683,
#      'formattedAddress': ['Потемкинская, 9', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.94539324266473,
#        'lng': 30.36753068915487}],
#      'lat': 59.94539324266473,
#      'lng': 30.36753068915487,
#      'state': 'Санкт-Петербург'},
#     'name': 'British Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'primary': True,
#       'shortName': 'Breakfast'}],
#     'hasPerk': False,
#     'id': '5bbf30f865211f002c283386',
#     'location': {'address': 'Кирочная 12',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1918,
#      'formattedAddress': ['Кирочная 12', '191028, Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.944054,
#        'lng': 30.353542}],
#      'lat': 59.944054,
#      'lng': 30.353542,
#      'postalCode': '191028',
#      'state': 'Санкт-Петербург'},
#     'name': 'Мама Люба Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '5968c2971ffed7567b5a362e',
#     'location': {'address': 'Малая Конюшенная ул., 16/26',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Невский просп.',
#      'distance': 79,
#      'formattedAddress': ['Малая Конюшенная ул., 16/26 (Невский просп.)',
#       '191186, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.93576544039898,
#        'lng': 30.324910251879714}],
#      'lat': 59.93576544039898,
#      'lng': 30.324910251879714,
#      'postalCode': '191186',
#      'state': 'Санкт-Петербург'},
#     'name': 'British Bakery (Британские пекарни)',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'primary': True,
#       'shortName': 'Vegetarian / Vegan'}],
#     'hasPerk': False,
#     'id': '5ae5d36ddd8442002ce69462',
#     'location': {'address': 'Лиговский проспект 50',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 2298,
#      'formattedAddress': ['Лиговский проспект 50',
#       '191040, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.925115219286944,
#        'lng': 30.358959577953318}],
#      'lat': 59.925115219286944,
#      'lng': 30.358959577953318,
#      'postalCode': '191040',
#      'state': 'Санкт-Петербург'},
#     'name': 'Veggie Box Food & Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4e402ecc8877b00cfc6a4e17',
#     'location': {'address': 'ул. Малая Морская, 13/8',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 610,
#      'formattedAddress': ['ул. Малая Морская, 13/8',
#       '191186, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.9355864641618,
#        'lng': 30.31255468658117}],
#      'lat': 59.9355864641618,
#      'lng': 30.31255468658117,
#      'postalCode': '191186',
#      'state': 'Санкт-Петербург'},
#     'name': 'Гости',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'primary': True,
#       'shortName': 'Desserts'}],
#     'hasPerk': False,
#     'id': '5b33a6056fd626002c9f3b1d',
#     'location': {'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1942,
#      'formattedAddress': ['197198, Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.9507,
#        'lng': 30.305893}],
#      'lat': 59.9507,
#      'lng': 30.305893,
#      'postalCode': '197198',
#      'state': 'Санкт-Петербург'},
#     'name': 'Eat&Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'primary': True,
#       'shortName': 'Desserts'}],
#     'hasPerk': False,
#     'id': '5531696d498e3a2ddd8f2eeb',
#     'location': {'address': 'Кожевенная линия, 30',
#      'cc': 'RU',
#      'country': 'Россия',
#      'distance': 4359,
#      'formattedAddress': ['Кожевенная линия, 30', '199106', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92273838031304,
#        'lng': 30.249706989571457}],
#      'lat': 59.92273838031304,
#      'lng': 30.249706989571457,
#      'postalCode': '199106',
#      'state': 'Санкт-Петербург'},
#     'name': "Арт-кондитерская Alia's bakery",
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '5280935611d20569c33daeef',
#     'location': {'address': 'ТРЦ «Лондон Молл»',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'ул. Коллонтай, 3',
#      'distance': 7314,
#      'formattedAddress': ['ТРЦ «Лондон Молл» (ул. Коллонтай, 3)',
#       '193313, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.911991167627065,
#        'lng': 30.4458369651204}],
#      'lat': 59.911991167627065,
#      'lng': 30.4458369651204,
#      'postalCode': '193313',
#      'state': 'Санкт-Петербург'},
#     'name': 'British Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'primary': True,
#       'shortName': 'Coffee Shop'}],
#     'hasPerk': False,
#     'id': '5bbf39bfe1f0aa002c5279cf',
#     'location': {'address': 'Кирочная 12',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1924,
#      'formattedAddress': ['Кирочная 12', '191028, Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.944006,
#        'lng': 30.353709}],
#      'lat': 59.944006,
#      'lng': 30.353709,
#      'postalCode': '191028',
#      'state': 'Санкт-Петербург'},
#     'name': 'Мама Люба Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '50fbd784e4b0687cddb0f5f0',
#     'location': {'address': 'Crowne Plaza',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Стартовая ул., 6, лит. А',
#      'distance': 14402,
#      'formattedAddress': ['Crowne Plaza (Стартовая ул., 6, лит. А)',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.80632169619755,
#        'lng': 30.31597260445848}],
#      'lat': 59.80632169619755,
#      'lng': 30.31597260445848,
#      'state': 'Санкт-Петербург'},
#     'name': 'Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '597b39c68496ca0b432b84e0',
#     'location': {'address': 'ул. Маршала Казакова, 78, корп. 1',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 11551,
#      'formattedAddress': ['ул. Маршала Казакова, 78, корп. 1',
#       '198332, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.869094540158045,
#        'lng': 30.164736185678557}],
#      'lat': 59.869094540158045,
#      'lng': 30.164736185678557,
#      'postalCode': '198332',
#      'state': 'Санкт-Петербург'},
#     'name': 'A&K Bakery Shop',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '5a3bdb2731ac6c2279d1918e',
#     'location': {'address': 'Кременчугская 17 К.3',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 3044,
#      'formattedAddress': ['Кременчугская 17 К.3',
#       '191167, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.920934,
#        'lng': 30.369509}],
#      'lat': 59.920934,
#      'lng': 30.369509,
#      'postalCode': '191167',
#      'state': 'Санкт-Петербург'},
#     'name': 'Craft Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'primary': True,
#       'shortName': 'Café'}],
#     'hasPerk': False,
#     'id': '5aec31f1a6031c002c8e6654',
#     'location': {'address': '26-я Линия Дом 15Б',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 3757,
#      'formattedAddress': ['26-я Линия Дом 15Б',
#       '199106, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.932599,
#        'lng': 30.256404}],
#      'lat': 59.932599,
#      'lng': 30.256404,
#      'postalCode': '199106',
#      'state': 'Санкт-Петербург'},
#     'name': 'Eat&Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '5c38836cd4cc98002bfa4467',
#     'location': {'address': 'Загородный просп., 52',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1804,
#      'formattedAddress': ['Загородный просп., 52',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.91963837212363,
#        'lng': 30.32855629915503}],
#      'lat': 59.91963837212363,
#      'lng': 30.32855629915503,
#      'state': 'Санкт-Петербург'},
#     'name': 'Пекарня Ширшов / Shirshov Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '577f894d498eb58cba70bda8',
#     'location': {'address': 'Балтийская улица, 22',
#      'cc': 'RU',
#      'country': 'Россия',
#      'distance': 4683,
#      'formattedAddress': ['Балтийская улица, 22', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.89866538971242,
#        'lng': 30.28346366380352}],
#      'lat': 59.89866538971242,
#      'lng': 30.28346366380352,
#      'state': 'Санкт-Петербург'},
#     'name': 'BAKERY "Shirshov & Co"',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'primary': True,
#       'shortName': 'Bakery'}],
#     'hasPerk': False,
#     'id': '5380545e498e044fe31a2e1a',
#     'location': {'address': 'ул. Оптиков, 51, корп. 1',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 10335,
#      'formattedAddress': ['ул. Оптиков, 51, корп. 1',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 60.00336920762823,
#        'lng': 30.196585715829706}],
#      'lat': 60.00336920762823,
#      'lng': 30.196585715829706,
#      'state': 'Санкт-Петербург'},
#     'name': 'Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'primary': True,
#       'shortName': 'Vegetarian / Vegan'}],
#     'hasPerk': False,
#     'id': '56472566498efa95139b2d44',
#     'location': {'address': 'Лиговский просп., 50',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 2293,
#      'formattedAddress': ['Лиговский просп., 50',
#       '191040, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.925037,
#        'lng': 30.358755}],
#      'lat': 59.925037,
#      'lng': 30.358755,
#      'neighborhood': 'Ligovka-Yamskaya Municipal Okrug',
#      'postalCode': '191040',
#      'state': 'Санкт-Петербург'},
#     'name': 'Veggie Box Food & Bakery',
#     'referralId': 'v-1550174336'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'primary': True,
#       'shortName': 'Desserts'}],
#     'hasPerk': False,
#     'id': '575f42f6498e0ca819cf2243',
#     'location': {'address': 'Лиговский проспект 74',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 2345,
#      'formattedAddress': ['Лиговский проспект 74',
#       '191040, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.922069,
#        'lng': 30.355664}],
#      'lat': 59.922069,
#      'lng': 30.355664,
#      'postalCode': '191040',
#      'state': 'Санкт-Петербург'},
#     'name': "Papa's Pie Bakery",
#     'referralId': 'v-1550174336'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Bakery', 'icon': {'prefix': 'h...    False
# 1  [{'shortName': 'Bakery', 'icon': {'prefix': 'h...    False
# 2  [{'shortName': 'Bakery', 'icon': {'prefix': 'h...    False
# 3  [{'shortName': 'Bakery', 'icon': {'prefix': 'h...    False
# 4  [{'shortName': 'Desserts', 'icon': {'prefix': ...    False
#
#                          id          location.address location.cc  \
# 0  4cac69f35a1e9521858d8ece  ТЦ «Владимирский Пассаж»          RU
# 1  4f6ab59ce4b01a6dd5564f05      Греческий просп., 25          RU
# 2  4ca49c67d7c33704febfaa62   Большой просп. П.С., 80          RU
# 3  5042161fe4b0a10506dd7bb8              ТЦ «Электра»          RU
# 4  5230626311d22f9e9d411cd5              ТРК «Радуга»          RU
#
#      location.city location.country     location.crossStreet  \
# 0  Санкт-Петербург           Россия  Владимирский просп., 19
# 1  Санкт-Петербург           Россия        8-я Советская ул.
# 2  Санкт-Петербург           Россия            ул. Плуталова
# 3  Санкт-Петербург           Россия   Московский просп., 137
# 4  Санкт-Петербург           Россия   просп. Космонавтов, 14
#
#    location.distance                          location.formattedAddress  \
# 0               1546  [ТЦ «Владимирский Пассаж» (Владимирский просп....
# 1               2585  [Греческий просп., 25 (8-я Советская ул.), 191...
# 2               3243  [Большой просп. П.С., 80 (ул. Плуталова), 1971...
# 3               6092  [ТЦ «Электра» (Московский просп., 137), 196105...
# 4               7508  [ТРК «Радуга» (просп. Космонавтов, 14), Санкт-...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lng': 30.34719816837263, 'lat': 59.92842988...     59.928430
# 1  [{'lng': 30.369622844811605, 'lat': 59.9380419...     59.938042
# 2  [{'lng': 30.3086342677935, 'lat': 59.963812494...     59.963812
# 3  [{'lng': 30.318230421980388, 'lat': 59.8809796...     59.880980
# 4  [{'lng': 30.349766027315997, 'lat': 59.8694954...     59.869495
#
#    location.lng location.neighborhood location.postalCode   location.state  \
# 0     30.347198                   NaN              190000  Санкт-Петербург
# 1     30.369623                   NaN              191036  Санкт-Петербург
# 2     30.308634                   NaN              197136  Санкт-Петербург
# 3     30.318230                   NaN              196105  Санкт-Петербург
# 4     30.349766                   NaN                 NaN  Санкт-Петербург
#
#                                   name    referralId
# 0  British Bakery / Британские пекарни  v-1550174336
# 1  British Bakery / Британские пекарни  v-1550174336
# 2  British Bakery / Британские пекарни  v-1550174336
# 3  British Bakery / Британские пекарни  v-1550174336
# 4                       British Bakery  v-1550174336

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                    name                     categories  \
# 0   British Bakery / Британские пекарни                         Bakery
# 1   British Bakery / Британские пекарни                         Bakery
# 2   British Bakery / Британские пекарни                         Bakery
# 3   British Bakery / Британские пекарни                         Bakery
# 4                        British Bakery                   Dessert Shop
# 5   British Bakery / Британские пекарни                         Bakery
# 6   British Bakery (Британские пекарни)                         Bakery
# 7                          Мишка Bakery                         Bakery
# 8                         Babe's Bakery                    Coffee Shop
# 9                                  Буше                         Bakery
# 10              Sisters Coffee & Bakery                           Café
# 11                         мишка Bakery                         Bakery
# 12                       British Bakery                         Bakery
# 13                     Мама Люба Bakery                 Breakfast Spot
# 14  British Bakery (Британские пекарни)                         Bakery
# 15             Veggie Box Food & Bakery  Vegetarian / Vegan Restaurant
# 16                                Гости                     Restaurant
# 17                           Eat&Bakery                   Dessert Shop
# 18       Арт-кондитерская Alia's bakery                   Dessert Shop
# 19                       British Bakery                         Bakery
# 20                     Мама Люба Bakery                    Coffee Shop
# 21                               Bakery                         Bakery
# 22                      A&K Bakery Shop                         Bakery
# 23                         Craft Bakery                         Bakery
# 24                           Eat&Bakery                           Café
# 25     Пекарня Ширшов / Shirshov Bakery                         Bakery
# 26               BAKERY "Shirshov & Co"                         Bakery
# 27                               Bakery                         Bakery
# 28             Veggie Box Food & Bakery  Vegetarian / Vegan Restaurant
# 29                    Papa's Pie Bakery                   Dessert Shop
#
#                               address  cc             city country  \
# 0            ТЦ «Владимирский Пассаж»  RU  Санкт-Петербург  Россия
# 1                Греческий просп., 25  RU  Санкт-Петербург  Россия
# 2             Большой просп. П.С., 80  RU  Санкт-Петербург  Россия
# 3                        ТЦ «Электра»  RU  Санкт-Петербург  Россия
# 4                        ТРК «Радуга»  RU  Санкт-Петербург  Россия
# 5            Новочеркасский пр. 41/14  RU  Санкт-Петербург  Россия
# 6                  ТРК «Гранд Каньон»  RU  Санкт-Петербург  Россия
# 7        102 Фонтанки реки набережная  RU  Санкт-Петербург  Россия
# 8                      ул. Марата, 30  RU  Санкт-Петербург  Россия
# 9                Малая Морская ул., 7  RU  Санкт-Петербург  Россия
# 10         наб. Обводного канала, 108  RU  Санкт-Петербург  Россия
# 11                                NaN  RU  Санкт-Петербург  Россия
# 12                    Потемкинская, 9  RU  Санкт-Петербург  Россия
# 13                        Кирочная 12  RU  Санкт-Петербург  Россия
# 14        Малая Конюшенная ул., 16/26  RU  Санкт-Петербург  Россия
# 15              Лиговский проспект 50  RU  Санкт-Петербург  Россия
# 16            ул. Малая Морская, 13/8  RU  Санкт-Петербург  Россия
# 17                                NaN  RU  Санкт-Петербург  Россия
# 18               Кожевенная линия, 30  RU              NaN  Россия
# 19                  ТРЦ «Лондон Молл»  RU  Санкт-Петербург  Россия
# 20                        Кирочная 12  RU  Санкт-Петербург  Россия
# 21                       Crowne Plaza  RU  Санкт-Петербург  Россия
# 22  ул. Маршала Казакова, 78, корп. 1  RU  Санкт-Петербург  Россия
# 23               Кременчугская 17 К.3  RU  Санкт-Петербург  Россия
# 24                 26-я Линия Дом 15Б  RU  Санкт-Петербург  Россия
# 25              Загородный просп., 52  RU  Санкт-Петербург  Россия
# 26               Балтийская улица, 22  RU              NaN  Россия
# 27           ул. Оптиков, 51, корп. 1  RU  Санкт-Петербург  Россия
# 28               Лиговский просп., 50  RU  Санкт-Петербург  Россия
# 29              Лиговский проспект 74  RU  Санкт-Петербург  Россия
#
#                  crossStreet  distance  \
# 0    Владимирский просп., 19      1546
# 1          8-я Советская ул.      2585
# 2              ул. Плуталова      3243
# 3     Московский просп., 137      6092
# 4     просп. Космонавтов, 14      7508
# 5                        NaN      4920
# 6       просп. Энгельса, 154     13712
# 7                        NaN      1347
# 8                        NaN      1903
# 9                        NaN       552
# 10                       NaN      3177
# 11                       NaN     12006
# 12                       NaN      2683
# 13                       NaN      1918
# 14            Невский просп.        79
# 15                       NaN      2298
# 16                       NaN       610
# 17                       NaN      1942
# 18                       NaN      4359
# 19          ул. Коллонтай, 3      7314
# 20                       NaN      1924
# 21  Стартовая ул., 6, лит. А     14402
# 22                       NaN     11551
# 23                       NaN      3044
# 24                       NaN      3757
# 25                       NaN      1804
# 26                       NaN      4683
# 27                       NaN     10335
# 28                       NaN      2293
# 29                       NaN      2345
#
#                                      formattedAddress  \
# 0   [ТЦ «Владимирский Пассаж» (Владимирский просп....
# 1   [Греческий просп., 25 (8-я Советская ул.), 191...
# 2   [Большой просп. П.С., 80 (ул. Плуталова), 1971...
# 3   [ТЦ «Электра» (Московский просп., 137), 196105...
# 4   [ТРК «Радуга» (просп. Космонавтов, 14), Санкт-...
# 5   [Новочеркасский пр. 41/14, Санкт-Петербург, Ро...
# 6   [ТРК «Гранд Каньон» (просп. Энгельса, 154), 19...
# 7   [102 Фонтанки реки набережная, 191180, Санкт-П...
# 8   [ул. Марата, 30, 191040, Санкт-Петербург, Россия]
# 9   [Малая Морская ул., 7, 191186, Санкт-Петербург...
# 10  [наб. Обводного канала, 108, 196084, Санкт-Пет...
# 11                  [196158, Санкт-Петербург, Россия]
# 12         [Потемкинская, 9, Санкт-Петербург, Россия]
# 13     [Кирочная 12, 191028, Санкт-Петербург, Россия]
# 14  [Малая Конюшенная ул., 16/26 (Невский просп.),...
# 15  [Лиговский проспект 50, 191040, Санкт-Петербур...
# 16  [ул. Малая Морская, 13/8, 191186, Санкт-Петерб...
# 17                  [197198, Санкт-Петербург, Россия]
# 18             [Кожевенная линия, 30, 199106, Россия]
# 19  [ТРЦ «Лондон Молл» (ул. Коллонтай, 3), 193313,...
# 20     [Кирочная 12, 191028, Санкт-Петербург, Россия]
# 21  [Crowne Plaza (Стартовая ул., 6, лит. А), Санк...
# 22  [ул. Маршала Казакова, 78, корп. 1, 198332, Са...
# 23  [Кременчугская 17 К.3, 191167, Санкт-Петербург...
# 24  [26-я Линия Дом 15Б, 199106, Санкт-Петербург, ...
# 25   [Загородный просп., 52, Санкт-Петербург, Россия]
# 26                     [Балтийская улица, 22, Россия]
# 27  [ул. Оптиков, 51, корп. 1, Санкт-Петербург, Ро...
# 28  [Лиговский просп., 50, 191040, Санкт-Петербург...
# 29  [Лиговский проспект 74, 191040, Санкт-Петербур...
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'lng': 30.34719816837263, 'lat': 59.92842988...  59.928430  30.347198
# 1   [{'lng': 30.369622844811605, 'lat': 59.9380419...  59.938042  30.369623
# 2   [{'lng': 30.3086342677935, 'lat': 59.963812494...  59.963812  30.308634
# 3   [{'lng': 30.318230421980388, 'lat': 59.8809796...  59.880980  30.318230
# 4   [{'lng': 30.349766027315997, 'lat': 59.8694954...  59.869495  30.349766
# 5   [{'lng': 30.410845737340207, 'lat': 59.9294280...  59.929428  30.410846
# 6   [{'lng': 30.336684295048464, 'lat': 60.0586514...  60.058651  30.336684
# 7   [{'lng': 30.324066163107787, 'lat': 59.9235461...  59.923546  30.324066
# 8   [{'lng': 30.352257914923825, 'lat': 59.9264374...  59.926437  30.352258
# 9   [{'lng': 30.313610535583198, 'lat': 59.9359595...  59.935960  30.313611
# 10  [{'lng': 30.31225957615085, 'lat': 59.90766570...  59.907666  30.312260
# 11  [{'lng': 30.325792, 'lat': 59.827793, 'label':...  59.827793  30.325792
# 12  [{'lng': 30.36753068915487, 'lat': 59.94539324...  59.945393  30.367531
# 13  [{'lng': 30.353542, 'lat': 59.944054, 'label':...  59.944054  30.353542
# 14  [{'lng': 30.324910251879714, 'lat': 59.9357654...  59.935765  30.324910
# 15  [{'lng': 30.358959577953318, 'lat': 59.9251152...  59.925115  30.358960
# 16  [{'lng': 30.31255468658117, 'lat': 59.93558646...  59.935586  30.312555
# 17  [{'lng': 30.305893, 'lat': 59.9507, 'label': '...  59.950700  30.305893
# 18  [{'lng': 30.249706989571457, 'lat': 59.9227383...  59.922738  30.249707
# 19  [{'lng': 30.4458369651204, 'lat': 59.911991167...  59.911991  30.445837
# 20  [{'lng': 30.353709, 'lat': 59.944006, 'label':...  59.944006  30.353709
# 21  [{'lng': 30.31597260445848, 'lat': 59.80632169...  59.806322  30.315973
# 22  [{'lng': 30.164736185678557, 'lat': 59.8690945...  59.869095  30.164736
# 23  [{'lng': 30.369509, 'lat': 59.920934, 'label':...  59.920934  30.369509
# 24  [{'lng': 30.256404, 'lat': 59.932599, 'label':...  59.932599  30.256404
# 25  [{'lng': 30.32855629915503, 'lat': 59.91963837...  59.919638  30.328556
# 26  [{'lng': 30.28346366380352, 'lat': 59.89866538...  59.898665  30.283464
# 27  [{'lng': 30.196585715829706, 'lat': 60.0033692...  60.003369  30.196586
# 28  [{'lng': 30.358755, 'lat': 59.925037, 'label':...  59.925037  30.358755
# 29  [{'lng': 30.355664, 'lat': 59.922069, 'label':...  59.922069  30.355664
#
#                         neighborhood postalCode            state  \
# 0                                NaN     190000  Санкт-Петербург
# 1                                NaN     191036  Санкт-Петербург
# 2                                NaN     197136  Санкт-Петербург
# 3                                NaN     196105  Санкт-Петербург
# 4                                NaN        NaN  Санкт-Петербург
# 5                                NaN        NaN  Санкт-Петербург
# 6                                NaN     194358  Санкт-Петербург
# 7                                NaN     191180  Санкт-Петербург
# 8                                NaN     191040  Санкт-Петербург
# 9                                NaN     191186  Санкт-Петербург
# 10                               NaN     196084  Санкт-Петербург
# 11                    Округ Звёздное     196158  Санкт-Петербург
# 12                               NaN        NaN  Санкт-Петербург
# 13                               NaN     191028  Санкт-Петербург
# 14                               NaN     191186  Санкт-Петербург
# 15                               NaN     191040  Санкт-Петербург
# 16                               NaN     191186  Санкт-Петербург
# 17                               NaN     197198  Санкт-Петербург
# 18                               NaN     199106  Санкт-Петербург
# 19                               NaN     193313  Санкт-Петербург
# 20                               NaN     191028  Санкт-Петербург
# 21                               NaN        NaN  Санкт-Петербург
# 22                               NaN     198332  Санкт-Петербург
# 23                               NaN     191167  Санкт-Петербург
# 24                               NaN     199106  Санкт-Петербург
# 25                               NaN        NaN  Санкт-Петербург
# 26                               NaN        NaN  Санкт-Петербург
# 27                               NaN        NaN  Санкт-Петербург
# 28  Ligovka-Yamskaya Municipal Okrug     191040  Санкт-Петербург
# 29                               NaN     191040  Санкт-Петербург
#
#                           id
# 0   4cac69f35a1e9521858d8ece
# 1   4f6ab59ce4b01a6dd5564f05
# 2   4ca49c67d7c33704febfaa62
# 3   5042161fe4b0a10506dd7bb8
# 4   5230626311d22f9e9d411cd5
# 5   56cdad3fcd100886b3be7795
# 6   4cc927047151721ebc246537
# 7   594562113af9883484e27ef3
# 8   59c3a1db2e268037db0e254e
# 9   4bb593bb941ad13af0641ee3
# 10  596bfb5cc0cacb4451055242
# 11  5b6019bcb1538e002c1cfa4f
# 12  53637d27498e173691316bc2
# 13  5bbf30f865211f002c283386
# 14  5968c2971ffed7567b5a362e
# 15  5ae5d36ddd8442002ce69462
# 16  4e402ecc8877b00cfc6a4e17
# 17  5b33a6056fd626002c9f3b1d
# 18  5531696d498e3a2ddd8f2eeb
# 19  5280935611d20569c33daeef
# 20  5bbf39bfe1f0aa002c5279cf
# 21  50fbd784e4b0687cddb0f5f0
# 22  597b39c68496ca0b432b84e0
# 23  5a3bdb2731ac6c2279d1918e
# 24  5aec31f1a6031c002c8e6654
# 25  5c38836cd4cc98002bfa4467
# 26  577f894d498eb58cba70bda8
# 27  5380545e498e044fe31a2e1a
# 28  56472566498efa95139b2d44
# 29  575f42f6498e0ca819cf2243

# %%
dataframe_filtered.name
# Out:
# 0     British Bakery / Британские пекарни
# 1     British Bakery / Британские пекарни
# 2     British Bakery / Британские пекарни
# 3     British Bakery / Британские пекарни
# 4                          British Bakery
# 5     British Bakery / Британские пекарни
# 6     British Bakery (Британские пекарни)
# 7                            Мишка Bakery
# 8                           Babe's Bakery
# 9                                    Буше
# 10                Sisters Coffee & Bakery
# 11                           мишка Bakery
# 12                         British Bakery
# 13                       Мама Люба Bakery
# 14    British Bakery (Британские пекарни)
# 15               Veggie Box Food & Bakery
# 16                                  Гости
# 17                             Eat&Bakery
# 18         Арт-кондитерская Alia's bakery
# 19                         British Bakery
# 20                       Мама Люба Bakery
# 21                                 Bakery
# 22                        A&K Bakery Shop
# 23                           Craft Bakery
# 24                             Eat&Bakery
# 25       Пекарня Ширшов / Shirshov Bakery
# 26                 BAKERY "Shirshov & Co"
# 27                                 Bakery
# 28               Veggie Box Food & Bakery
# 29                      Papa's Pie Bakery
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the St. Petrsburg
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
