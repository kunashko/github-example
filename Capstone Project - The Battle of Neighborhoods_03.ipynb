# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.18.1                     py_0    conda-forge
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'RUWENN41AQNZCAN1GGZU5DOAWFN2BGP1CDMYS42EOWHV1UKI' # your Foursquare ID
CLIENT_SECRET = 'AVQNOUSATC1LPMERL4EESPIYPH1GLXSKHAJVGVFTTAV4SHY1' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 10000
print('Your credentails:')
print('CLIENT_ID:' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID:RUWENN41AQNZCAN1GGZU5DOAWFN2BGP1CDMYS42EOWHV1UKI
# CLIENT_SECRET:AVQNOUSATC1LPMERL4EESPIYPH1GLXSKHAJVGVFTTAV4SHY1

# %%
address = 'Nevsky prospect, St. Petersburg, Russian Federation'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 59.9356467 30.3235057

# %%
search_query = 'Pub'
radius = 15000
print(search_query + ' .... OK!')
# Out:
# Pub .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RUWENN41AQNZCAN1GGZU5DOAWFN2BGP1CDMYS42EOWHV1UKI&client_secret=AVQNOUSATC1LPMERL4EESPIYPH1GLXSKHAJVGVFTTAV4SHY1&ll=59.9356467,30.3235057&v=20180604&query=Pub&radius=15000&limit=10000'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c65cdaef594df7dc9c54ce3'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4c210d43132f0f47f3aca796',
#     'location': {'address': 'Невский просп., 22',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 81,
#      'formattedAddress': ['Невский просп., 22',
#       '191186, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.936261,
#        'lng': 30.322727}],
#      'lat': 59.936261,
#      'lng': 30.322727,
#      'postalCode': '191186',
#      'state': 'Санкт-Петербург'},
#     'name': 'Tower Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4cb9fa88bac93704486de87c',
#     'location': {'address': 'Невский просп., 38',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 417,
#      'formattedAddress': ['Невский просп., 38', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.934919656165796,
#        'lng': 30.33084139326995}],
#      'lat': 59.934919656165796,
#      'lng': 30.33084139326995,
#      'state': 'Санкт-Петербург'},
#     'name': 'Rock-Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4bbb6cbb1261d13a51a9eb98',
#     'location': {'address': 'Шведский пер., 2',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Малая Конюшенная ул.',
#      'distance': 374,
#      'formattedAddress': ['Шведский пер., 2 (Малая Конюшенная ул.)',
#       '191186, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.93877303050877,
#        'lng': 30.325985724027355}],
#      'lat': 59.93877303050877,
#      'lng': 30.325985724027355,
#      'postalCode': '191186',
#      'state': 'Санкт-Петербург'},
#     'name': 'James Cook Pub & Cafe',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4b9c0540f964a520974136e3',
#     'location': {'address': 'ул. Рубинштейна, 36',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1409,
#      'formattedAddress': ['ул. Рубинштейна, 36',
#       '191002, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92769316085189,
#        'lng': 30.3431777092165}],
#      'lat': 59.92769316085189,
#      'lng': 30.3431777092165,
#      'postalCode': '191002',
#      'state': 'Санкт-Петербург'},
#     'name': "Mollie's Pub / Моллис",
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4c14c54ba9c220a1f206589d',
#     'location': {'address': 'ул. Ефимова, 3',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1093,
#      'formattedAddress': ['ул. Ефимова, 3',
#       '190031, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92596262819126,
#        'lng': 30.32021944306114}],
#      'lat': 59.92596262819126,
#      'lng': 30.32021944306114,
#      'postalCode': '190031',
#      'state': 'Санкт-Петербург'},
#     'name': 'Shilling British Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4bc8997915a7ef3bfe6a7bda',
#     'location': {'address': 'Казанская ул., 5',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 295,
#      'formattedAddress': ['Казанская ул., 5',
#       '191186, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.933074897996036,
#        'lng': 30.322170056321827}],
#      'lat': 59.933074897996036,
#      'lng': 30.322170056321827,
#      'postalCode': '191186',
#      'state': 'Санкт-Петербург'},
#     'name': 'The Office Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '5990ad98a879210716d90182',
#     'location': {'address': 'Римского-Корсакова 1',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Садовая',
#      'distance': 1414,
#      'formattedAddress': ['Римского-Корсакова 1 (Садовая)',
#       '190068, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92439906359565,
#        'lng': 30.311721867948997}],
#      'lat': 59.92439906359565,
#      'lng': 30.311721867948997,
#      'postalCode': '190068',
#      'state': 'Санкт-Петербург'},
#     'name': 'London Pub',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '441715445'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4c64066bfa7bc92873f31127',
#     'location': {'address': 'ул. Марата, 36/38',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1929,
#      'formattedAddress': ['ул. Марата, 36/38', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92573867413496,
#        'lng': 30.35189567441112}],
#      'lat': 59.92573867413496,
#      'lng': 30.35189567441112,
#      'state': 'Санкт-Петербург'},
#     'name': 'Бристоль паб / Bristol Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11d941735',
#       'name': 'Sports Bar',
#       'pluralName': 'Sports Bars',
#       'primary': True,
#       'shortName': 'Sports Bar'}],
#     'hasPerk': False,
#     'id': '4c52d7f92d51952175e74590',
#     'location': {'address': 'РТК «Варшавский Экспресс»',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'наб. Обводного канала, 118',
#      'distance': 3305,
#      'formattedAddress': ['РТК «Варшавский Экспресс» (наб. Обводного канала, 118)',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.90708035418232,
#        'lng': 30.307353731418374}],
#      'lat': 59.90708035418232,
#      'lng': 30.307353731418374,
#      'state': 'Санкт-Петербург'},
#     'name': 'Спорт Паб 84 / Sport pub 84',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '69818010'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4f855a96e4b0e90cd45bfad5',
#     'location': {'address': 'ул. Белинского, 3',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1237,
#      'formattedAddress': ['ул. Белинского, 3',
#       '191014, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.938114,
#        'lng': 30.345144}],
#      'lat': 59.938114,
#      'lng': 30.345144,
#      'postalCode': '191014',
#      'state': 'Санкт-Петербург'},
#     'name': 'Oliver Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4c8e049dd68c6dcbcc46f8a1',
#     'location': {'address': 'ул. Куйбышева, 23',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 2547,
#      'formattedAddress': ['ул. Куйбышева, 23', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.958239269473054,
#        'lng': 30.33074664424837}],
#      'lat': 59.958239269473054,
#      'lng': 30.33074664424837,
#      'state': 'Санкт-Петербург'},
#     'name': 'Tower Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b7a06',
#       'name': 'Irish Pub',
#       'pluralName': 'Irish Pubs',
#       'primary': True,
#       'shortName': 'Irish'}],
#     'hasPerk': False,
#     'id': '4c210c1f7e85c9280ce4b921',
#     'location': {'address': 'Большая Конюшенная ул., 14',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 115,
#      'formattedAddress': ['Большая Конюшенная ул., 14',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.93657044162746,
#        'lng': 30.322580993023372}],
#      'lat': 59.93657044162746,
#      'lng': 30.322580993023372,
#      'state': 'Санкт-Петербург'},
#     'name': "O'Hooligans",
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '565c512d498edfd416405c12',
#     'location': {'address': 'Разъезжая 11',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1663,
#      'formattedAddress': ['Разъезжая 11', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.925073871863795,
#        'lng': 30.34457373434634}],
#      'lat': 59.925073871863795,
#      'lng': 30.34457373434634,
#      'state': 'Санкт-Петербург'},
#     'name': "Dog's Nose Pub",
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f1931735',
#       'name': 'General Entertainment',
#       'pluralName': 'General Entertainment',
#       'primary': True,
#       'shortName': 'Entertainment'}],
#     'hasPerk': False,
#     'id': '559ba97a498eaee4838d1947',
#     'location': {'address': 'ул. Жуковского, 15',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1647,
#      'formattedAddress': ['ул. Жуковского, 15',
#       '191014, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.936048451598765,
#        'lng': 30.35302873081612}],
#      'lat': 59.936048451598765,
#      'lng': 30.35302873081612,
#      'postalCode': '191014',
#      'state': 'Санкт-Петербург г.\xa0 (Sankt-Peterburg g.)'},
#     'name': 'City Pub Crawl - Saint - Petersburg / Тур по барам Санкт-Петербурга',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '133647007'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '520e41bd11d2ec48fdd4374d',
#     'location': {'address': 'Гончарная ул., 24',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 2746,
#      'formattedAddress': ['Гончарная ул., 24', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92777673443127,
#        'lng': 30.370174094480415}],
#      'lat': 59.92777673443127,
#      'lng': 30.370174094480415,
#      'state': 'Санкт-Петербург'},
#     'name': 'Rugby House Pub',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '69822283'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '56bded45498ec2feafba853e',
#     'location': {'address': 'ул. Маяковского, 16',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1755,
#      'formattedAddress': ['ул. Маяковского, 16', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.9362116186223,
#        'lng': 30.35496986877056}],
#      'lat': 59.9362116186223,
#      'lng': 30.35496986877056,
#      'state': 'Санкт-Петербург'},
#     'name': 'Corleone Pub',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '224671145'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4fafcfcde4b0afbb676e7b69',
#     'location': {'address': 'Коломяжский просп., 15',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 7421,
#      'formattedAddress': ['Коломяжский просп., 15',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 60.001176913282244,
#        'lng': 30.29896941532707}],
#      'lat': 60.001176913282244,
#      'lng': 30.29896941532707,
#      'state': 'Санкт-Петербург'},
#     'name': 'Rock-Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '576bac25498eda44b2e1870d',
#     'location': {'address': 'Невский проспект 53',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1581,
#      'formattedAddress': ['Невский проспект 53',
#       '191025, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.931981,
#        'lng': 30.350898}],
#      'lat': 59.931981,
#      'lng': 30.350898,
#      'postalCode': '191025',
#      'state': 'Санкт-Петербург'},
#     'name': 'Secret Service Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '57cd6c94498ece3483572758',
#     'location': {'address': 'Большой просп. П. C., 82',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 3262,
#      'formattedAddress': ['Большой просп. П. C., 82',
#       '197136, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.964044626549025,
#        'lng': 30.309054273890535}],
#      'lat': 59.964044626549025,
#      'lng': 30.309054273890535,
#      'postalCode': '197136',
#      'state': 'Санкт-Петербург'},
#     'name': 'The Red Fox Pub',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '458921384'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b7a06',
#       'name': 'Irish Pub',
#       'pluralName': 'Irish Pubs',
#       'primary': True,
#       'shortName': 'Irish'}],
#     'hasPerk': False,
#     'id': '567d827e498ecedadf6ddf3e',
#     'location': {'address': 'ул. Адмирала Трибуца, 7',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 13608,
#      'formattedAddress': ['ул. Адмирала Трибуца, 7',
#       '198206, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.85175799934679,
#        'lng': 30.146232247352597}],
#      'lat': 59.85175799934679,
#      'lng': 30.146232247352597,
#      'postalCode': '198206',
#      'state': 'Санкт-Петербург'},
#     'name': 'MacNamara Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '5152dfebe4b0ed45a8f9b764',
#     'location': {'address': 'Пионерская ул., 11',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 2890,
#      'formattedAddress': ['Пионерская ул., 11', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.95670508413652,
#        'lng': 30.293172479845}],
#      'lat': 59.95670508413652,
#      'lng': 30.293172479845,
#      'state': 'Санкт-Петербург'},
#     'name': 'The Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '564c5209498e8ed3e51ca2a4',
#     'location': {'address': 'Кирочная ул., 17',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'просп. Чернышевского',
#      'distance': 2189,
#      'formattedAddress': ['Кирочная ул., 17 (просп. Чернышевского)',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.943819300559916,
#        'lng': 30.359219885743606}],
#      'lat': 59.943819300559916,
#      'lng': 30.359219885743606,
#      'state': 'Санкт-Петербург'},
#     'name': 'Black Wood Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4c88df2f94f5a093cf08d31e',
#     'location': {'address': 'ТРК «Континент»',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Байконурская ул., 14А',
#      'distance': 7954,
#      'formattedAddress': ['ТРК «Континент» (Байконурская ул., 14А)',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 60.002456059250484,
#        'lng': 30.272835184456987}],
#      'lat': 60.002456059250484,
#      'lng': 30.272835184456987,
#      'state': 'Санкт-Петербург'},
#     'name': 'Шиллинг / Shilling Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'primary': True,
#       'shortName': 'Nightclub'}],
#     'hasPerk': False,
#     'id': '52504e69498e0a9b52f4d08a',
#     'location': {'cc': 'RU',
#      'country': 'Россия',
#      'distance': 732,
#      'formattedAddress': ['Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.937141,
#        'lng': 30.336292}],
#      'lat': 59.937141,
#      'lng': 30.336292},
#     'name': 'PROSTO KPEM @ Кино Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'primary': True,
#       'shortName': 'Park'}],
#     'hasPerk': False,
#     'id': '4c36b0863849c9283c8bbcb1',
#     'location': {'address': 'пл. Островского',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 784,
#      'formattedAddress': ['пл. Островского', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.933692450190165,
#        'lng': 30.33701958131764}],
#      'lat': 59.933692450190165,
#      'lng': 30.33701958131764,
#      'state': 'Санкт-Петербург'},
#     'name': 'Catherine Public Garden (Екатерининский сквер)',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b7a06',
#       'name': 'Irish Pub',
#       'pluralName': 'Irish Pubs',
#       'primary': True,
#       'shortName': 'Irish'}],
#     'hasPerk': False,
#     'id': '4e78d181b993adb6be21b2e7',
#     'location': {'address': 'Большая Конюшенная ул., 5',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 507,
#      'formattedAddress': ['Большая Конюшенная ул., 5',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.94020076595651,
#        'lng': 30.32400001848442}],
#      'lat': 59.94020076595651,
#      'lng': 30.32400001848442,
#      'state': 'Санкт-Петербург'},
#     'name': 'Mollie`s Mews / Моллис Мьюз',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '80487831'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'primary': True,
#       'shortName': 'Gastropub'}],
#     'hasPerk': False,
#     'id': '5a1d9059bfc6d03f263a6342',
#     'location': {'address': 'Кирочная ул., 11',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1956,
#      'formattedAddress': ['Кирочная ул., 11',
#       '191014, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.943855,
#        'lng': 30.354535}],
#      'lat': 59.943855,
#      'lng': 30.354535,
#      'postalCode': '191014',
#      'state': 'Санкт-Петербург'},
#     'name': 'My Friends Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4c9df77f46978cfa2e7c9c7f',
#     'location': {'address': 'Фурштатская ул., 9',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1970,
#      'formattedAddress': ['Фурштатская ул., 9', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.94528325964919,
#        'lng': 30.353145400575247}],
#      'lat': 59.94528325964919,
#      'lng': 30.353145400575247,
#      'state': 'Санкт-Петербург'},
#     'name': 'Golden Pint Pub',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '97608523'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '56aa371ce4b08b9a8d57356c',
#       'name': 'Beer Bar',
#       'pluralName': 'Beer Bars',
#       'primary': True,
#       'shortName': 'Beer Bar'}],
#     'hasPerk': False,
#     'id': '5c1a7b0128374e002cc7c8ec',
#     'location': {'address': 'Port Sevkabel, Kojevennaya line 40 E',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 4768,
#      'formattedAddress': ['Port Sevkabel, Kojevennaya line 40 E',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92433429999999,
#        'lng': 30.241050200000018}],
#      'lat': 59.92433429999999,
#      'lng': 30.241050200000018,
#      'neighborhood': 'Округ Гавань',
#      'state': 'Санкт-Петербург'},
#     'name': 'Axiom Pub SPb.',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '52e7d548498ecd851e540782',
#     'location': {'address': 'Малый просп. П.С., 55, лит. А',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Лахтинская ул.',
#      'distance': 3254,
#      'formattedAddress': ['Малый просп. П.С., 55, лит. А (Лахтинская ул.)',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.96249454119248,
#        'lng': 30.300385796473126}],
#      'lat': 59.96249454119248,
#      'lng': 30.300385796473126,
#      'state': 'Санкт-Петербург'},
#     'name': 'The Corner Pub',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '371816162'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '57cad540498e17c45738ea4f',
#     'location': {'address': 'Набережная канала Грибоедова, 107',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1699,
#      'formattedAddress': ['Набережная канала Грибоедова, 107',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92581662283393,
#        'lng': 30.30018877833187}],
#      'lat': 59.92581662283393,
#      'lng': 30.30018877833187,
#      'state': 'Санкт-Петербург'},
#     'name': 'Gladstone Home pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4c12566fb7b9c928518fa737',
#     'location': {'address': 'наб. р. Фонтанки, 108',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Московский просп.',
#      'distance': 1558,
#      'formattedAddress': ['наб. р. Фонтанки, 108 (Московский просп.)',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92184204225978,
#        'lng': 30.318822912047413}],
#      'lat': 59.92184204225978,
#      'lng': 30.318822912047413,
#      'state': 'Санкт-Петербург'},
#     'name': 'Dickens (Диккенс)',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '56238306498e997b040c7b24',
#     'location': {'address': 'Стремянная ул., 8',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1594,
#      'formattedAddress': ['Стремянная ул., 8',
#       '191025, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.93104,
#        'lng': 30.350574}],
#      'lat': 59.93104,
#      'lng': 30.350574,
#      'postalCode': '191025',
#      'state': 'Санкт-Петербург'},
#     'name': 'The Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '5c46177465211f002cbac3ff',
#     'location': {'address': 'Рубинштейна 1, третий этаж',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Невский проспект',
#      'distance': 1284,
#      'formattedAddress': ['Рубинштейна 1, третий этаж (Невский проспект)',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.93246719175686,
#        'lng': 30.345641076564785}],
#      'lat': 59.93246719175686,
#      'lng': 30.345641076564785,
#      'state': 'Санкт-Петербург'},
#     'name': 'Сommode PUB',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '4e0a020a8877394591f740ff',
#     'location': {'address': 'Пулковское ш., 3',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 10559,
#      'formattedAddress': ['Пулковское ш., 3', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.84083479584466,
#        'lng': 30.317710464160914}],
#      'lat': 59.84083479584466,
#      'lng': 30.317710464160914,
#      'state': 'Санкт-Петербург'},
#     'name': 'The Red Fox Pub',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '458684967'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b7a06',
#       'name': 'Irish Pub',
#       'pluralName': 'Irish Pubs',
#       'primary': True,
#       'shortName': 'Irish'}],
#     'hasPerk': False,
#     'id': '4f48fc30e4b01d17ba5218fd',
#     'location': {'address': 'Адмиралтейский просп., 8',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Гороховая ул., 1',
#      'distance': 777,
#      'formattedAddress': ['Адмиралтейский просп., 8 (Гороховая ул., 1)',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.93595854327076,
#        'lng': 30.309576094150543}],
#      'lat': 59.93595854327076,
#      'lng': 30.309576094150543,
#      'state': 'Санкт-Петербург'},
#     'name': 'Radio Ireland',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '83176474'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'primary': True,
#       'shortName': 'Gastropub'}],
#     'hasPerk': False,
#     'id': '57b4c26b498ec4fb5342dc47',
#     'location': {'address': 'Невский 53',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1507,
#      'formattedAddress': ['Невский 53', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.932167,
#        'lng': 30.349636}],
#      'lat': 59.932167,
#      'lng': 30.349636,
#      'state': 'Санкт-Петербург'},
#     'name': "It's Pub Time",
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '54e327ef498e0c237b4ac61e',
#     'location': {'cc': 'RU',
#      'country': 'Россия',
#      'distance': 1306,
#      'formattedAddress': ['Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.94020254898573,
#        'lng': 30.34508903755175}],
#      'lat': 59.94020254898573,
#      'lng': 30.34508903755175},
#     'name': 'Mix Pub BBQ',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '546f52e6498e0e46bdc20c2e',
#     'location': {'address': 'просп. Стачек, 55',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Комсомольская площадь',
#      'distance': 7452,
#      'formattedAddress': ['просп. Стачек, 55 (Комсомольская площадь)',
#       '198096, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.87732499136932,
#        'lng': 30.257962346076965}],
#      'lat': 59.87732499136932,
#      'lng': 30.257962346076965,
#      'postalCode': '198096',
#      'state': 'Санкт-Петербург'},
#     'name': 'Pub Black beeR',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '161095259'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '527b6a5c498e3a66a10dc0a7',
#     'location': {'address': 'Выборгское ш., 17, корп. 1',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 13222,
#      'formattedAddress': ['Выборгское ш., 17, корп. 1',
#       '194355, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 60.054257092084086,
#        'lng': 30.31082069922693}],
#      'lat': 60.054257092084086,
#      'lng': 30.31082069922693,
#      'postalCode': '194355',
#      'state': 'Санкт-Петербург'},
#     'name': 'PUBTHEPUB',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '75213111'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'primary': True,
#       'shortName': 'Gastropub'}],
#     'hasPerk': False,
#     'id': '5b294757535d6f002c377852',
#     'location': {'address': 'Ленинский пр., д.104',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 10805,
#      'formattedAddress': ['Ленинский пр., д.104',
#       '198303, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.852107437454606,
#        'lng': 30.224955322175}],
#      'lat': 59.852107437454606,
#      'lng': 30.224955322175,
#      'neighborhood': 'Округ Красненькая речка',
#      'postalCode': '198303',
#      'state': 'Санкт-Петербург'},
#     'name': 'склад pub&kitchen',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '566c2b59498e58d3adf21165',
#     'location': {'address': 'Кушелевская дор., 3, корп. 2',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 6387,
#      'formattedAddress': ['Кушелевская дор., 3, корп. 2',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.98820064710963,
#        'lng': 30.36952387393931}],
#      'lat': 59.98820064710963,
#      'lng': 30.36952387393931,
#      'state': 'Санкт-Петербург'},
#     'name': 'My Little Pub',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b7a06',
#       'name': 'Irish Pub',
#       'pluralName': 'Irish Pubs',
#       'primary': True,
#       'shortName': 'Irish'}],
#     'hasPerk': False,
#     'id': '4c12a15e7f7f2d7f52a9dd68',
#     'location': {'address': 'ул. Некрасова, 37/20',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'crossStreet': 'Радищева',
#      'distance': 2251,
#      'formattedAddress': ['ул. Некрасова, 37/20 (Радищева)',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.93862162089012,
#        'lng': 30.36343662825104}],
#      'lat': 59.93862162089012,
#      'lng': 30.36343662825104,
#      'state': 'Санкт-Петербург'},
#     'name': 'The Templet Bar',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'primary': True,
#       'shortName': 'Pub'}],
#     'hasPerk': False,
#     'id': '56ee8619498e6f88689902df',
#     'location': {'address': 'ул. Радищева, 8',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 2178,
#      'formattedAddress': ['ул. Радищева, 8', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.93691893738358,
#        'lng': 30.362484432681153}],
#      'lat': 59.93691893738358,
#      'lng': 30.362484432681153,
#      'state': 'Санкт-Петербург'},
#     'name': "Oi Mate 'Pub",
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'primary': True,
#       'shortName': 'Gastropub'}],
#     'hasPerk': False,
#     'id': '5343c3d3498e47a49570393a',
#     'location': {'address': 'Одоевского 32',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 5186,
#      'formattedAddress': ['Одоевского 32', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.94812961037696,
#        'lng': 30.233879644785837}],
#      'lat': 59.94812961037696,
#      'lng': 30.233879644785837,
#      'state': 'Санкт-Петербург'},
#     'name': 'RiverSide Pub&Grill',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '539dd03c498e08a9ddc79dd1',
#     'location': {'address': 'Ул. Марата, 57',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 2015,
#      'formattedAddress': ['Ул. Марата, 57', 'Санкт-Петербург', 'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.92217176515408,
#        'lng': 30.34763142595904}],
#      'lat': 59.92217176515408,
#      'lng': 30.34763142595904,
#      'state': 'Санкт-Петербург'},
#     'name': "ReJoin Gamer's Pub",
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b7a06',
#       'name': 'Irish Pub',
#       'pluralName': 'Irish Pubs',
#       'primary': True,
#       'shortName': 'Irish'}],
#     'hasPerk': False,
#     'id': '57e15742cd109d598325e65f',
#     'location': {'address': 'Невский проспект 112',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 1997,
#      'formattedAddress': ['Невский проспект 112',
#       '191025, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.932516,
#        'lng': 30.358764}],
#      'lat': 59.932516,
#      'lng': 30.358764,
#      'postalCode': '191025',
#      'state': 'Санкт-Петербург'},
#     'name': "irish pub linnegan's",
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '5540abb6498e9804fb263114',
#     'location': {'address': 'Большой Проспект В.О. 8/4',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 2067,
#      'formattedAddress': ['Большой Проспект В.О. 8/4',
#       'Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.940552799182434,
#        'lng': 30.287749827776885}],
#      'lat': 59.940552799182434,
#      'lng': 30.287749827776885,
#      'state': 'Санкт-Петербург'},
#     'name': 'Maler pub&bar',
#     'referralId': 'v-1550175662'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'primary': True,
#       'shortName': 'Gastropub'}],
#     'hasPerk': False,
#     'id': '51a473a4498e84820af223ed',
#     'location': {'address': 'наб. Макарова, 22',
#      'cc': 'RU',
#      'city': 'Санкт-Петербург',
#      'country': 'Россия',
#      'distance': 2540,
#      'formattedAddress': ['наб. Макарова, 22',
#       '199004, Санкт-Петербург',
#       'Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.94765840986013,
#        'lng': 30.284769319085697}],
#      'lat': 59.94765840986013,
#      'lng': 30.284769319085697,
#      'postalCode': '199004',
#      'state': 'Санкт-Петербург'},
#     'name': 'Брюгге',
#     'referralId': 'v-1550175662',
#     'venuePage': {'id': '59160615'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b7a06',
#       'name': 'Irish Pub',
#       'pluralName': 'Irish Pubs',
#       'primary': True,
#       'shortName': 'Irish'}],
#     'hasPerk': False,
#     'id': '5475b604498e156b2207e6a6',
#     'location': {'cc': 'RU',
#      'country': 'Россия',
#      'distance': 2007,
#      'formattedAddress': ['Россия'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 59.924937,
#        'lng': 30.352455}],
#      'lat': 59.924937,
#      'lng': 30.352455},
#     'name': 'John-Donne Pub',
#     'referralId': 'v-1550175662'}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'shortName': 'Pub', 'icon': {'prefix': 'http...    False
# 1  [{'shortName': 'Pub', 'icon': {'prefix': 'http...    False
# 2  [{'shortName': 'Pub', 'icon': {'prefix': 'http...    False
# 3  [{'shortName': 'Pub', 'icon': {'prefix': 'http...    False
# 4  [{'shortName': 'Pub', 'icon': {'prefix': 'http...    False
#
#                          id     location.address location.cc    location.city  \
# 0  4c210d43132f0f47f3aca796   Невский просп., 22          RU  Санкт-Петербург
# 1  4cb9fa88bac93704486de87c   Невский просп., 38          RU  Санкт-Петербург
# 2  4bbb6cbb1261d13a51a9eb98     Шведский пер., 2          RU  Санкт-Петербург
# 3  4b9c0540f964a520974136e3  ул. Рубинштейна, 36          RU  Санкт-Петербург
# 4  4c14c54ba9c220a1f206589d       ул. Ефимова, 3          RU  Санкт-Петербург
#
#   location.country  location.crossStreet  location.distance  \
# 0           Россия                   NaN                 81
# 1           Россия                   NaN                417
# 2           Россия  Малая Конюшенная ул.                374
# 3           Россия                   NaN               1409
# 4           Россия                   NaN               1093
#
#                            location.formattedAddress  \
# 0  [Невский просп., 22, 191186, Санкт-Петербург, ...
# 1      [Невский просп., 38, Санкт-Петербург, Россия]
# 2  [Шведский пер., 2 (Малая Конюшенная ул.), 1911...
# 3  [ул. Рубинштейна, 36, 191002, Санкт-Петербург,...
# 4  [ул. Ефимова, 3, 190031, Санкт-Петербург, Россия]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'lng': 30.322727, 'lat': 59.936261, 'label':...     59.936261
# 1  [{'lng': 30.33084139326995, 'lat': 59.93491965...     59.934920
# 2  [{'lng': 30.325985724027355, 'lat': 59.9387730...     59.938773
# 3  [{'lng': 30.3431777092165, 'lat': 59.927693160...     59.927693
# 4  [{'lng': 30.32021944306114, 'lat': 59.92596262...     59.925963
#
#    location.lng location.neighborhood location.postalCode   location.state  \
# 0     30.322727                   NaN              191186  Санкт-Петербург
# 1     30.330841                   NaN                 NaN  Санкт-Петербург
# 2     30.325986                   NaN              191186  Санкт-Петербург
# 3     30.343178                   NaN              191002  Санкт-Петербург
# 4     30.320219                   NaN              190031  Санкт-Петербург
#
#                     name    referralId venuePage.id
# 0              Tower Pub  v-1550175662          NaN
# 1               Rock-Pub  v-1550175662          NaN
# 2  James Cook Pub & Cafe  v-1550175662          NaN
# 3  Mollie's Pub / Моллис  v-1550175662          NaN
# 4   Shilling British Pub  v-1550175662          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name             categories  \
# 0                                           Tower Pub                    Pub
# 1                                            Rock-Pub                    Pub
# 2                               James Cook Pub & Cafe                    Pub
# 3                               Mollie's Pub / Моллис                    Pub
# 4                                Shilling British Pub                    Pub
# 5                                      The Office Pub                    Pub
# 6                                          London Pub                    Pub
# 7                          Бристоль паб / Bristol Pub                    Pub
# 8                         Спорт Паб 84 / Sport pub 84             Sports Bar
# 9                                          Oliver Pub                    Pub
# 10                                          Tower Pub                    Pub
# 11                                        O'Hooligans              Irish Pub
# 12                                     Dog's Nose Pub                    Pub
# 13  City Pub Crawl - Saint - Petersburg / Тур по б...  General Entertainment
# 14                                    Rugby House Pub                    Pub
# 15                                       Corleone Pub                    Pub
# 16                                           Rock-Pub                    Pub
# 17                                 Secret Service Pub                    Pub
# 18                                    The Red Fox Pub                    Pub
# 19                                      MacNamara Pub              Irish Pub
# 20                                            The Pub                    Pub
# 21                                     Black Wood Pub                    Pub
# 22                             Шиллинг / Shilling Pub                    Pub
# 23                             PROSTO KPEM @ Кино Pub              Nightclub
# 24     Catherine Public Garden (Екатерининский сквер)                   Park
# 25                        Mollie`s Mews / Моллис Мьюз              Irish Pub
# 26                                     My Friends Pub              Gastropub
# 27                                    Golden Pint Pub                    Pub
# 28                                     Axiom Pub SPb.               Beer Bar
# 29                                     The Corner Pub                    Pub
# 30                                 Gladstone Home pub                    Pub
# 31                                  Dickens (Диккенс)                    Pub
# 32                                            The Pub             Restaurant
# 33                                        Сommode PUB                    Bar
# 34                                    The Red Fox Pub                    Pub
# 35                                      Radio Ireland              Irish Pub
# 36                                      It's Pub Time              Gastropub
# 37                                        Mix Pub BBQ                    Pub
# 38                                     Pub Black beeR                    Pub
# 39                                          PUBTHEPUB             Restaurant
# 40                                  склад pub&kitchen              Gastropub
# 41                                      My Little Pub                    Pub
# 42                                    The Templet Bar              Irish Pub
# 43                                       Oi Mate 'Pub                    Pub
# 44                                RiverSide Pub&Grill              Gastropub
# 45                                 ReJoin Gamer's Pub                    Bar
# 46                               irish pub linnegan's              Irish Pub
# 47                                      Maler pub&bar                    Bar
# 48                                             Брюгге              Gastropub
# 49                                     John-Donne Pub              Irish Pub
#
#                                  address  cc             city country  \
# 0                     Невский просп., 22  RU  Санкт-Петербург  Россия
# 1                     Невский просп., 38  RU  Санкт-Петербург  Россия
# 2                       Шведский пер., 2  RU  Санкт-Петербург  Россия
# 3                    ул. Рубинштейна, 36  RU  Санкт-Петербург  Россия
# 4                         ул. Ефимова, 3  RU  Санкт-Петербург  Россия
# 5                       Казанская ул., 5  RU  Санкт-Петербург  Россия
# 6                   Римского-Корсакова 1  RU  Санкт-Петербург  Россия
# 7                      ул. Марата, 36/38  RU  Санкт-Петербург  Россия
# 8              РТК «Варшавский Экспресс»  RU  Санкт-Петербург  Россия
# 9                      ул. Белинского, 3  RU  Санкт-Петербург  Россия
# 10                     ул. Куйбышева, 23  RU  Санкт-Петербург  Россия
# 11            Большая Конюшенная ул., 14  RU  Санкт-Петербург  Россия
# 12                          Разъезжая 11  RU  Санкт-Петербург  Россия
# 13                    ул. Жуковского, 15  RU  Санкт-Петербург  Россия
# 14                     Гончарная ул., 24  RU  Санкт-Петербург  Россия
# 15                   ул. Маяковского, 16  RU  Санкт-Петербург  Россия
# 16                Коломяжский просп., 15  RU  Санкт-Петербург  Россия
# 17                   Невский проспект 53  RU  Санкт-Петербург  Россия
# 18              Большой просп. П. C., 82  RU  Санкт-Петербург  Россия
# 19               ул. Адмирала Трибуца, 7  RU  Санкт-Петербург  Россия
# 20                    Пионерская ул., 11  RU  Санкт-Петербург  Россия
# 21                      Кирочная ул., 17  RU  Санкт-Петербург  Россия
# 22                       ТРК «Континент»  RU  Санкт-Петербург  Россия
# 23                                   NaN  RU              NaN  Россия
# 24                       пл. Островского  RU  Санкт-Петербург  Россия
# 25             Большая Конюшенная ул., 5  RU  Санкт-Петербург  Россия
# 26                      Кирочная ул., 11  RU  Санкт-Петербург  Россия
# 27                    Фурштатская ул., 9  RU  Санкт-Петербург  Россия
# 28  Port Sevkabel, Kojevennaya line 40 E  RU  Санкт-Петербург  Россия
# 29         Малый просп. П.С., 55, лит. А  RU  Санкт-Петербург  Россия
# 30     Набережная канала Грибоедова, 107  RU  Санкт-Петербург  Россия
# 31                 наб. р. Фонтанки, 108  RU  Санкт-Петербург  Россия
# 32                     Стремянная ул., 8  RU  Санкт-Петербург  Россия
# 33            Рубинштейна 1, третий этаж  RU  Санкт-Петербург  Россия
# 34                      Пулковское ш., 3  RU  Санкт-Петербург  Россия
# 35              Адмиралтейский просп., 8  RU  Санкт-Петербург  Россия
# 36                            Невский 53  RU  Санкт-Петербург  Россия
# 37                                   NaN  RU              NaN  Россия
# 38                     просп. Стачек, 55  RU  Санкт-Петербург  Россия
# 39            Выборгское ш., 17, корп. 1  RU  Санкт-Петербург  Россия
# 40                  Ленинский пр., д.104  RU  Санкт-Петербург  Россия
# 41          Кушелевская дор., 3, корп. 2  RU  Санкт-Петербург  Россия
# 42                  ул. Некрасова, 37/20  RU  Санкт-Петербург  Россия
# 43                       ул. Радищева, 8  RU  Санкт-Петербург  Россия
# 44                         Одоевского 32  RU  Санкт-Петербург  Россия
# 45                        Ул. Марата, 57  RU  Санкт-Петербург  Россия
# 46                  Невский проспект 112  RU  Санкт-Петербург  Россия
# 47             Большой Проспект В.О. 8/4  RU  Санкт-Петербург  Россия
# 48                     наб. Макарова, 22  RU  Санкт-Петербург  Россия
# 49                                   NaN  RU              NaN  Россия
#
#                    crossStreet  distance  \
# 0                          NaN        81
# 1                          NaN       417
# 2         Малая Конюшенная ул.       374
# 3                          NaN      1409
# 4                          NaN      1093
# 5                          NaN       295
# 6                      Садовая      1414
# 7                          NaN      1929
# 8   наб. Обводного канала, 118      3305
# 9                          NaN      1237
# 10                         NaN      2547
# 11                         NaN       115
# 12                         NaN      1663
# 13                         NaN      1647
# 14                         NaN      2746
# 15                         NaN      1755
# 16                         NaN      7421
# 17                         NaN      1581
# 18                         NaN      3262
# 19                         NaN     13608
# 20                         NaN      2890
# 21        просп. Чернышевского      2189
# 22       Байконурская ул., 14А      7954
# 23                         NaN       732
# 24                         NaN       784
# 25                         NaN       507
# 26                         NaN      1956
# 27                         NaN      1970
# 28                         NaN      4768
# 29              Лахтинская ул.      3254
# 30                         NaN      1699
# 31           Московский просп.      1558
# 32                         NaN      1594
# 33            Невский проспект      1284
# 34                         NaN     10559
# 35            Гороховая ул., 1       777
# 36                         NaN      1507
# 37                         NaN      1306
# 38       Комсомольская площадь      7452
# 39                         NaN     13222
# 40                         NaN     10805
# 41                         NaN      6387
# 42                    Радищева      2251
# 43                         NaN      2178
# 44                         NaN      5186
# 45                         NaN      2015
# 46                         NaN      1997
# 47                         NaN      2067
# 48                         NaN      2540
# 49                         NaN      2007
#
#                                      formattedAddress  \
# 0   [Невский просп., 22, 191186, Санкт-Петербург, ...
# 1       [Невский просп., 38, Санкт-Петербург, Россия]
# 2   [Шведский пер., 2 (Малая Конюшенная ул.), 1911...
# 3   [ул. Рубинштейна, 36, 191002, Санкт-Петербург,...
# 4   [ул. Ефимова, 3, 190031, Санкт-Петербург, Россия]
# 5   [Казанская ул., 5, 191186, Санкт-Петербург, Ро...
# 6   [Римского-Корсакова 1 (Садовая), 190068, Санкт...
# 7        [ул. Марата, 36/38, Санкт-Петербург, Россия]
# 8   [РТК «Варшавский Экспресс» (наб. Обводного кан...
# 9   [ул. Белинского, 3, 191014, Санкт-Петербург, Р...
# 10       [ул. Куйбышева, 23, Санкт-Петербург, Россия]
# 11  [Большая Конюшенная ул., 14, Санкт-Петербург, ...
# 12            [Разъезжая 11, Санкт-Петербург, Россия]
# 13  [ул. Жуковского, 15, 191014, Санкт-Петербург, ...
# 14       [Гончарная ул., 24, Санкт-Петербург, Россия]
# 15     [ул. Маяковского, 16, Санкт-Петербург, Россия]
# 16  [Коломяжский просп., 15, Санкт-Петербург, Россия]
# 17  [Невский проспект 53, 191025, Санкт-Петербург,...
# 18  [Большой просп. П. C., 82, 197136, Санкт-Петер...
# 19  [ул. Адмирала Трибуца, 7, 198206, Санкт-Петерб...
# 20      [Пионерская ул., 11, Санкт-Петербург, Россия]
# 21  [Кирочная ул., 17 (просп. Чернышевского), Санк...
# 22  [ТРК «Континент» (Байконурская ул., 14А), Санк...
# 23                                           [Россия]
# 24         [пл. Островского, Санкт-Петербург, Россия]
# 25  [Большая Конюшенная ул., 5, Санкт-Петербург, Р...
# 26  [Кирочная ул., 11, 191014, Санкт-Петербург, Ро...
# 27      [Фурштатская ул., 9, Санкт-Петербург, Россия]
# 28  [Port Sevkabel, Kojevennaya line 40 E, Санкт-П...
# 29  [Малый просп. П.С., 55, лит. А (Лахтинская ул....
# 30  [Набережная канала Грибоедова, 107, Санкт-Пете...
# 31  [наб. р. Фонтанки, 108 (Московский просп.), Са...
# 32  [Стремянная ул., 8, 191025, Санкт-Петербург, Р...
# 33  [Рубинштейна 1, третий этаж (Невский проспект)...
# 34        [Пулковское ш., 3, Санкт-Петербург, Россия]
# 35  [Адмиралтейский просп., 8 (Гороховая ул., 1), ...
# 36              [Невский 53, Санкт-Петербург, Россия]
# 37                                           [Россия]
# 38  [просп. Стачек, 55 (Комсомольская площадь), 19...
# 39  [Выборгское ш., 17, корп. 1, 194355, Санкт-Пет...
# 40  [Ленинский пр., д.104, 198303, Санкт-Петербург...
# 41  [Кушелевская дор., 3, корп. 2, Санкт-Петербург...
# 42  [ул. Некрасова, 37/20 (Радищева), Санкт-Петерб...
# 43         [ул. Радищева, 8, Санкт-Петербург, Россия]
# 44           [Одоевского 32, Санкт-Петербург, Россия]
# 45          [Ул. Марата, 57, Санкт-Петербург, Россия]
# 46  [Невский проспект 112, 191025, Санкт-Петербург...
# 47  [Большой Проспект В.О. 8/4, Санкт-Петербург, Р...
# 48  [наб. Макарова, 22, 199004, Санкт-Петербург, Р...
# 49                                           [Россия]
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'lng': 30.322727, 'lat': 59.936261, 'label':...  59.936261  30.322727
# 1   [{'lng': 30.33084139326995, 'lat': 59.93491965...  59.934920  30.330841
# 2   [{'lng': 30.325985724027355, 'lat': 59.9387730...  59.938773  30.325986
# 3   [{'lng': 30.3431777092165, 'lat': 59.927693160...  59.927693  30.343178
# 4   [{'lng': 30.32021944306114, 'lat': 59.92596262...  59.925963  30.320219
# 5   [{'lng': 30.322170056321827, 'lat': 59.9330748...  59.933075  30.322170
# 6   [{'lng': 30.311721867948997, 'lat': 59.9243990...  59.924399  30.311722
# 7   [{'lng': 30.35189567441112, 'lat': 59.92573867...  59.925739  30.351896
# 8   [{'lng': 30.307353731418374, 'lat': 59.9070803...  59.907080  30.307354
# 9   [{'lng': 30.345144, 'lat': 59.938114, 'label':...  59.938114  30.345144
# 10  [{'lng': 30.33074664424837, 'lat': 59.95823926...  59.958239  30.330747
# 11  [{'lng': 30.322580993023372, 'lat': 59.9365704...  59.936570  30.322581
# 12  [{'lng': 30.34457373434634, 'lat': 59.92507387...  59.925074  30.344574
# 13  [{'lng': 30.35302873081612, 'lat': 59.93604845...  59.936048  30.353029
# 14  [{'lng': 30.370174094480415, 'lat': 59.9277767...  59.927777  30.370174
# 15  [{'lng': 30.35496986877056, 'lat': 59.93621161...  59.936212  30.354970
# 16  [{'lng': 30.29896941532707, 'lat': 60.00117691...  60.001177  30.298969
# 17  [{'lng': 30.350898, 'lat': 59.931981, 'label':...  59.931981  30.350898
# 18  [{'lng': 30.309054273890535, 'lat': 59.9640446...  59.964045  30.309054
# 19  [{'lng': 30.146232247352597, 'lat': 59.8517579...  59.851758  30.146232
# 20  [{'lng': 30.293172479845, 'lat': 59.9567050841...  59.956705  30.293172
# 21  [{'lng': 30.359219885743606, 'lat': 59.9438193...  59.943819  30.359220
# 22  [{'lng': 30.272835184456987, 'lat': 60.0024560...  60.002456  30.272835
# 23  [{'lng': 30.336292, 'lat': 59.937141, 'label':...  59.937141  30.336292
# 24  [{'lng': 30.33701958131764, 'lat': 59.93369245...  59.933692  30.337020
# 25  [{'lng': 30.32400001848442, 'lat': 59.94020076...  59.940201  30.324000
# 26  [{'lng': 30.354535, 'lat': 59.943855, 'label':...  59.943855  30.354535
# 27  [{'lng': 30.353145400575247, 'lat': 59.9452832...  59.945283  30.353145
# 28  [{'lng': 30.241050200000018, 'lat': 59.9243342...  59.924334  30.241050
# 29  [{'lng': 30.300385796473126, 'lat': 59.9624945...  59.962495  30.300386
# 30  [{'lng': 30.30018877833187, 'lat': 59.92581662...  59.925817  30.300189
# 31  [{'lng': 30.318822912047413, 'lat': 59.9218420...  59.921842  30.318823
# 32  [{'lng': 30.350574, 'lat': 59.93104, 'label': ...  59.931040  30.350574
# 33  [{'lng': 30.345641076564785, 'lat': 59.9324671...  59.932467  30.345641
# 34  [{'lng': 30.317710464160914, 'lat': 59.8408347...  59.840835  30.317710
# 35  [{'lng': 30.309576094150543, 'lat': 59.9359585...  59.935959  30.309576
# 36  [{'lng': 30.349636, 'lat': 59.932167, 'label':...  59.932167  30.349636
# 37  [{'lng': 30.34508903755175, 'lat': 59.94020254...  59.940203  30.345089
# 38  [{'lng': 30.257962346076965, 'lat': 59.8773249...  59.877325  30.257962
# 39  [{'lng': 30.31082069922693, 'lat': 60.05425709...  60.054257  30.310821
# 40  [{'lng': 30.224955322175, 'lat': 59.8521074374...  59.852107  30.224955
# 41  [{'lng': 30.36952387393931, 'lat': 59.98820064...  59.988201  30.369524
# 42  [{'lng': 30.36343662825104, 'lat': 59.93862162...  59.938622  30.363437
# 43  [{'lng': 30.362484432681153, 'lat': 59.9369189...  59.936919  30.362484
# 44  [{'lng': 30.233879644785837, 'lat': 59.9481296...  59.948130  30.233880
# 45  [{'lng': 30.34763142595904, 'lat': 59.92217176...  59.922172  30.347631
# 46  [{'lng': 30.358764, 'lat': 59.932516, 'label':...  59.932516  30.358764
# 47  [{'lng': 30.287749827776885, 'lat': 59.9405527...  59.940553  30.287750
# 48  [{'lng': 30.284769319085697, 'lat': 59.9476584...  59.947658  30.284769
# 49  [{'lng': 30.352455, 'lat': 59.924937, 'label':...  59.924937  30.352455
#
#                neighborhood postalCode  \
# 0                       NaN     191186
# 1                       NaN        NaN
# 2                       NaN     191186
# 3                       NaN     191002
# 4                       NaN     190031
# 5                       NaN     191186
# 6                       NaN     190068
# 7                       NaN        NaN
# 8                       NaN        NaN
# 9                       NaN     191014
# 10                      NaN        NaN
# 11                      NaN        NaN
# 12                      NaN        NaN
# 13                      NaN     191014
# 14                      NaN        NaN
# 15                      NaN        NaN
# 16                      NaN        NaN
# 17                      NaN     191025
# 18                      NaN     197136
# 19                      NaN     198206
# 20                      NaN        NaN
# 21                      NaN        NaN
# 22                      NaN        NaN
# 23                      NaN        NaN
# 24                      NaN        NaN
# 25                      NaN        NaN
# 26                      NaN     191014
# 27                      NaN        NaN
# 28             Округ Гавань        NaN
# 29                      NaN        NaN
# 30                      NaN        NaN
# 31                      NaN        NaN
# 32                      NaN     191025
# 33                      NaN        NaN
# 34                      NaN        NaN
# 35                      NaN        NaN
# 36                      NaN        NaN
# 37                      NaN        NaN
# 38                      NaN     198096
# 39                      NaN     194355
# 40  Округ Красненькая речка     198303
# 41                      NaN        NaN
# 42                      NaN        NaN
# 43                      NaN        NaN
# 44                      NaN        NaN
# 45                      NaN        NaN
# 46                      NaN     191025
# 47                      NaN        NaN
# 48                      NaN     199004
# 49                      NaN        NaN
#
#                                        state                        id
# 0                            Санкт-Петербург  4c210d43132f0f47f3aca796
# 1                            Санкт-Петербург  4cb9fa88bac93704486de87c
# 2                            Санкт-Петербург  4bbb6cbb1261d13a51a9eb98
# 3                            Санкт-Петербург  4b9c0540f964a520974136e3
# 4                            Санкт-Петербург  4c14c54ba9c220a1f206589d
# 5                            Санкт-Петербург  4bc8997915a7ef3bfe6a7bda
# 6                            Санкт-Петербург  5990ad98a879210716d90182
# 7                            Санкт-Петербург  4c64066bfa7bc92873f31127
# 8                            Санкт-Петербург  4c52d7f92d51952175e74590
# 9                            Санкт-Петербург  4f855a96e4b0e90cd45bfad5
# 10                           Санкт-Петербург  4c8e049dd68c6dcbcc46f8a1
# 11                           Санкт-Петербург  4c210c1f7e85c9280ce4b921
# 12                           Санкт-Петербург  565c512d498edfd416405c12
# 13  Санкт-Петербург г.  (Sankt-Peterburg g.)  559ba97a498eaee4838d1947
# 14                           Санкт-Петербург  520e41bd11d2ec48fdd4374d
# 15                           Санкт-Петербург  56bded45498ec2feafba853e
# 16                           Санкт-Петербург  4fafcfcde4b0afbb676e7b69
# 17                           Санкт-Петербург  576bac25498eda44b2e1870d
# 18                           Санкт-Петербург  57cd6c94498ece3483572758
# 19                           Санкт-Петербург  567d827e498ecedadf6ddf3e
# 20                           Санкт-Петербург  5152dfebe4b0ed45a8f9b764
# 21                           Санкт-Петербург  564c5209498e8ed3e51ca2a4
# 22                           Санкт-Петербург  4c88df2f94f5a093cf08d31e
# 23                                       NaN  52504e69498e0a9b52f4d08a
# 24                           Санкт-Петербург  4c36b0863849c9283c8bbcb1
# 25                           Санкт-Петербург  4e78d181b993adb6be21b2e7
# 26                           Санкт-Петербург  5a1d9059bfc6d03f263a6342
# 27                           Санкт-Петербург  4c9df77f46978cfa2e7c9c7f
# 28                           Санкт-Петербург  5c1a7b0128374e002cc7c8ec
# 29                           Санкт-Петербург  52e7d548498ecd851e540782
# 30                           Санкт-Петербург  57cad540498e17c45738ea4f
# 31                           Санкт-Петербург  4c12566fb7b9c928518fa737
# 32                           Санкт-Петербург  56238306498e997b040c7b24
# 33                           Санкт-Петербург  5c46177465211f002cbac3ff
# 34                           Санкт-Петербург  4e0a020a8877394591f740ff
# 35                           Санкт-Петербург  4f48fc30e4b01d17ba5218fd
# 36                           Санкт-Петербург  57b4c26b498ec4fb5342dc47
# 37                                       NaN  54e327ef498e0c237b4ac61e
# 38                           Санкт-Петербург  546f52e6498e0e46bdc20c2e
# 39                           Санкт-Петербург  527b6a5c498e3a66a10dc0a7
# 40                           Санкт-Петербург  5b294757535d6f002c377852
# 41                           Санкт-Петербург  566c2b59498e58d3adf21165
# 42                           Санкт-Петербург  4c12a15e7f7f2d7f52a9dd68
# 43                           Санкт-Петербург  56ee8619498e6f88689902df
# 44                           Санкт-Петербург  5343c3d3498e47a49570393a
# 45                           Санкт-Петербург  539dd03c498e08a9ddc79dd1
# 46                           Санкт-Петербург  57e15742cd109d598325e65f
# 47                           Санкт-Петербург  5540abb6498e9804fb263114
# 48                           Санкт-Петербург  51a473a4498e84820af223ed
# 49                                       NaN  5475b604498e156b2207e6a6

# %%
dataframe_filtered.name
# Out:
# 0                                             Tower Pub
# 1                                              Rock-Pub
# 2                                 James Cook Pub & Cafe
# 3                                 Mollie's Pub / Моллис
# 4                                  Shilling British Pub
# 5                                        The Office Pub
# 6                                            London Pub
# 7                            Бристоль паб / Bristol Pub
# 8                           Спорт Паб 84 / Sport pub 84
# 9                                            Oliver Pub
# 10                                            Tower Pub
# 11                                          O'Hooligans
# 12                                       Dog's Nose Pub
# 13    City Pub Crawl - Saint - Petersburg / Тур по б...
# 14                                      Rugby House Pub
# 15                                         Corleone Pub
# 16                                             Rock-Pub
# 17                                   Secret Service Pub
# 18                                      The Red Fox Pub
# 19                                        MacNamara Pub
# 20                                              The Pub
# 21                                       Black Wood Pub
# 22                               Шиллинг / Shilling Pub
# 23                               PROSTO KPEM @ Кино Pub
# 24       Catherine Public Garden (Екатерининский сквер)
# 25                          Mollie`s Mews / Моллис Мьюз
# 26                                       My Friends Pub
# 27                                      Golden Pint Pub
# 28                                       Axiom Pub SPb.
# 29                                       The Corner Pub
# 30                                   Gladstone Home pub
# 31                                    Dickens (Диккенс)
# 32                                              The Pub
# 33                                          Сommode PUB
# 34                                      The Red Fox Pub
# 35                                        Radio Ireland
# 36                                        It's Pub Time
# 37                                          Mix Pub BBQ
# 38                                       Pub Black beeR
# 39                                            PUBTHEPUB
# 40                                    склад pub&kitchen
# 41                                        My Little Pub
# 42                                      The Templet Bar
# 43                                         Oi Mate 'Pub
# 44                                  RiverSide Pub&Grill
# 45                                   ReJoin Gamer's Pub
# 46                                 irish pub linnegan's
# 47                                        Maler pub&bar
# 48                                               Брюгге
# 49                                       John-Donne Pub
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the St. Petrsburg
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
